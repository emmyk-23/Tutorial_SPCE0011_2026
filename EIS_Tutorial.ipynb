# %% [markdown]
# # Tutorial Session: Exploring Solar Spectra Using Hinode/EIS and Python

# %% [markdown]
# Welcome everyone!!!
# In this session, we are going to explore and learn how to analyse and use the spectroscopic data of the solar corona obtained from Hinode/EIS and SDO/AIA

# %% [markdown]
# We will use python in our project. However, we do not have install any program since we can run it on a browser through Google Colab. Colab allow us to connect to computer on google server and do our python stuff through Notebook like this one for certain amount of time.

# %% [markdown]
# Notebook is divided in to multiple cells which contains block of codes
# - You can run each cell by pressing Shift+Enter on keyboard
# - You can edit or mess around any code, it will not affect the actual source code unless you save it as a copy to github.
# - To comment each line of code (i.e, prevent that line of code from running), type # in front of the line.

# %% [markdown]
# Note that Colab does not store any data once we disconnect, so we have to install these libraries every time we start a new session.

# %% [markdown]
# ## Installing relevant modules

# %% [markdown]
# Some python libraries we are going to use today is not availiable on Colab. Therefore, we have to download them first using the command below.

# %%
# !pip install astropy>=5.1
# !pip install -q sunpy[all]
# !pip install -q eispac[all]
# !pip install -U sunkit-image
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.8/87.8 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 48.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 966.4/966.4 kB 51.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.0/98.0 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 76.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 81.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.8/96.8 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 350.3/350.3 kB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.7/79.7 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 68.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.9/101.9 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.0/191.0 kB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.8/378.8 kB 22.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.1/284.1 kB 17.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 89.5 MB/s eta 0:00:00
#   Building wheel for pims (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 37.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.1/171.1 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.2/364.2 kB 22.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 543.3/543.3 kB 30.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.3/59.3 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.8/253.8 kB 16.4 MB/s eta 0:00:00
#   Building wheel for eispac (setup.py) ... done
# Collecting sunkit-image
#   Downloading sunkit_image-0.6.1-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: astropy>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from sunkit-image) (7.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.12/dist-packages (from sunkit-image) (2.0.2)
# Requirement already satisfied: matplotlib>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from sunkit-image) (3.10.0)
# Requirement already satisfied: scipy>=1.10.1 in /usr/local/lib/python3.12/dist-packages (from sunkit-image) (1.16.3)
# Requirement already satisfied: scikit-image>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from sunkit-image) (0.25.2)
# Requirement already satisfied: sunpy>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[map]>=6.0.0->sunkit-image) (7.1.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.12/dist-packages (from astropy>=5.3.0->sunkit-image) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.10.27.0.39.10 in /usr/local/lib/python3.12/dist-packages (from astropy>=5.3.0->sunkit-image) (0.2026.1.12.0.42.13)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from astropy>=5.3.0->sunkit-image) (6.0.3)
# Requirement already satisfied: packaging>=22.0.0 in /usr/local/lib/python3.12/dist-packages (from astropy>=5.3.0->sunkit-image) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->sunkit-image) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->sunkit-image) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->sunkit-image) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->sunkit-image) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->sunkit-image) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->sunkit-image) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->sunkit-image) (2.9.0.post0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.20.0->sunkit-image) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.20.0->sunkit-image) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.20.0->sunkit-image) (2026.1.14)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.20.0->sunkit-image) (0.4)
# Requirement already satisfied: fsspec>=2023.6.0 in /usr/local/lib/python3.12/dist-packages (from sunpy>=6.0.0->sunpy[map]>=6.0.0->sunkit-image) (2025.3.0)
# Requirement already satisfied: parfive>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from parfive[ftp]>=2.1.0->sunpy>=6.0.0->sunpy[map]>=6.0.0->sunkit-image) (2.3.1)
# Requirement already satisfied: requests>=2.32.1 in /usr/local/lib/python3.12/dist-packages (from sunpy>=6.0.0->sunpy[map]>=6.0.0->sunkit-image) (2.32.4)
# Requirement already satisfied: mpl-animators>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[map]>=6.0.0->sunkit-image) (1.2.4)
# Requirement already satisfied: reproject>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[map]>=6.0.0->sunkit-image) (0.19.0)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.12/dist-packages (from parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy>=6.0.0->sunpy[map]>=6.0.0->sunkit-image) (4.67.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy>=6.0.0->sunpy[map]>=6.0.0->sunkit-image) (3.13.3)
# Requirement already satisfied: aioftp>=0.17.1 in /usr/local/lib/python3.12/dist-packages (from parfive[ftp]>=2.1.0->sunpy>=6.0.0->sunpy[map]>=6.0.0->sunkit-image) (0.27.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->sunkit-image) (1.17.0)
# Requirement already satisfied: astropy-healpix>=1.0 in /usr/local/lib/python3.12/dist-packages (from reproject>=0.13.0->sunpy[map]>=6.0.0->sunkit-image) (1.1.3)
# Requirement already satisfied: dask>=2024.4.1 in /usr/local/lib/python3.12/dist-packages (from dask[array]>=2024.4.1->reproject>=0.13.0->sunpy[map]>=6.0.0->sunkit-image) (2025.12.0)
# Requirement already satisfied: dask-image>=2025.11.0 in /usr/local/lib/python3.12/dist-packages (from reproject>=0.13.0->sunpy[map]>=6.0.0->sunkit-image) (2025.11.0)
# Requirement already satisfied: zarr>=2.17.0 in /usr/local/lib/python3.12/dist-packages (from reproject>=0.13.0->sunpy[map]>=6.0.0->sunkit-image) (3.1.5)
# Requirement already satisfied: pyavm>=0.9.6 in /usr/local/lib/python3.12/dist-packages (from reproject>=0.13.0->sunpy[map]>=6.0.0->sunkit-image) (0.9.8)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.1->sunpy>=6.0.0->sunpy[map]>=6.0.0->sunkit-image) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.1->sunpy>=6.0.0->sunpy[map]>=6.0.0->sunkit-image) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.1->sunpy>=6.0.0->sunpy[map]>=6.0.0->sunkit-image) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.1->sunpy>=6.0.0->sunpy[map]>=6.0.0->sunkit-image) (2026.1.4)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.4.1->dask[array]>=2024.4.1->reproject>=0.13.0->sunpy[map]>=6.0.0->sunkit-image) (8.3.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.4.1->dask[array]>=2024.4.1->reproject>=0.13.0->sunpy[map]>=6.0.0->sunkit-image) (3.1.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.4.1->dask[array]>=2024.4.1->reproject>=0.13.0->sunpy[map]>=6.0.0->sunkit-image) (1.4.2)
# Requirement already satisfied: toolz>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.4.1->dask[array]>=2024.4.1->reproject>=0.13.0->sunpy[map]>=6.0.0->sunkit-image) (0.12.1)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from dask-image>=2025.11.0->reproject>=0.13.0->sunpy[map]>=6.0.0->sunkit-image) (2.2.2)
# Requirement already satisfied: pims>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from dask-image>=2025.11.0->reproject>=0.13.0->sunpy[map]>=6.0.0->sunkit-image) (0.7)
# Requirement already satisfied: donfig>=0.8 in /usr/local/lib/python3.12/dist-packages (from zarr>=2.17.0->reproject>=0.13.0->sunpy[map]>=6.0.0->sunkit-image) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr>=2.17.0->reproject>=0.13.0->sunpy[map]>=6.0.0->sunkit-image) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in /usr/local/lib/python3.12/dist-packages (from zarr>=2.17.0->reproject>=0.13.0->sunpy[map]>=6.0.0->sunkit-image) (0.16.5)
# Requirement already satisfied: typing-extensions>=4.9 in /usr/local/lib/python3.12/dist-packages (from zarr>=2.17.0->reproject>=0.13.0->sunpy[map]>=6.0.0->sunkit-image) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy>=6.0.0->sunpy[map]>=6.0.0->sunkit-image) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy>=6.0.0->sunpy[map]>=6.0.0->sunkit-image) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy>=6.0.0->sunpy[map]>=6.0.0->sunkit-image) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy>=6.0.0->sunpy[map]>=6.0.0->sunkit-image) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy>=6.0.0->sunpy[map]>=6.0.0->sunkit-image) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy>=6.0.0->sunpy[map]>=6.0.0->sunkit-image) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy>=6.0.0->sunpy[map]>=6.0.0->sunkit-image) (1.22.0)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.12/dist-packages (from dask[array,dataframe]>=2024.4.1->dask-image>=2025.11.0->reproject>=0.13.0->sunpy[map]>=6.0.0->sunkit-image) (18.1.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->dask-image>=2025.11.0->reproject>=0.13.0->sunpy[map]>=6.0.0->sunkit-image) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->dask-image>=2025.11.0->reproject>=0.13.0->sunpy[map]>=6.0.0->sunkit-image) (2025.3)
# Requirement already satisfied: locket in /usr/local/lib/python3.12/dist-packages (from partd>=1.4.0->dask>=2024.4.1->dask[array]>=2024.4.1->reproject>=0.13.0->sunpy[map]>=6.0.0->sunkit-image) (1.0.0)
# Requirement already satisfied: slicerator>=0.9.8 in /usr/local/lib/python3.12/dist-packages (from pims>=0.4.1->dask-image>=2025.11.0->reproject>=0.13.0->sunpy[map]>=6.0.0->sunkit-image) (1.1.0)
# Downloading sunkit_image-0.6.1-py3-none-any.whl (6.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 50.2 MB/s eta 0:00:00
# Installing collected packages: sunkit-image
# Successfully installed sunkit-image-0.6.1

# %% [markdown]
# ## Load libraries we need for fitting spectral lines and making EIS maps

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
import sunpy
import sunpy.map
import sunkit_image.coalignment
from pathlib import Path
import os
import astropy.units as u
import eispac
# from eispac.net.attrs import FileType
from astropy.coordinates import SkyCoord
from sunpy.net import Fido,attrs as a
from sunpy.time import parse_time
from astropy.visualization import ImageNormalize

# list of templates for fitting some line profiles
templates_list = {
    'fe_10_184_536' : ['fe_10_184_536.1c.template.h5', 0],
    'fe_08_185_213' : ['fe_08_185_213.1c.template.h5', 0],
    'fe_11_188_216' : ['fe_11_188_216.2c.template.h5', 0],
    'fe_11_188_299' : ['fe_11_188_299.2c.template.h5', 1],
    'fe_09_188_497' : ['fe_09_188_497.3c.template.h5', 0],
    'ca_14_193_874' : ['ca_14_193_874.6c.template.h5', 1],
    'ar_14_194_396' : ['ar_14_194_396.6c.template.h5', 5],
    'fe_12_195_119' : ['fe_12_195_119.2c.template.h5', 0],
    'fe_13_201_121' : ['fe_13_201_121.2c.template.h5', 1],
    'fe_13_202_044' : ['fe_13_202_044.1c.template.h5', 0],
    'fe_13_203_826' : ['fe_13_203_826.2c.template.h5', 1],
    'si_10_258_375' : ['si_10_258_375.1c.template.h5', 0],
    'si_10_261_058' : ['si_10_261_058.1c.template.h5', 0],
    'fe_16_262_984' : ['fe_16_262_984.1c.template.h5', 0],
    's_10_264_233' : ['s__10_264_233.1c.template.h5', 0],
    'fe_14_264_787' : ['fe_14_264_787.1c.template.h5', 0],
    'fe_15_284_160' : ['fe_15_284_160.2c.template.h5', 1]}

# %% [markdown]
# ## Download the Hinode/EIS data from online database (May took a while)
#
# The prepped EIS data are stored at https://eis.nrl.navy.mil/

# %%
EISfile = eispac.db.download_hdf5_data('eis_20110208_153218.data.h5')
# Out:
#  + created data_eis
# + downloading https://eis.nrl.navy.mil/level1/hdf5/2011/02/08/eis_20110208_153218.data.h5 -> data_eis/eis_20110208_153218.data.h5
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# eis_20110208_153218.data.h5.part:   0%|          | 0.00/64.9M [00:00<?, ?B/s]
# + downloading https://eis.nrl.navy.mil/level1/hdf5/2011/02/08/eis_20110208_153218.head.h5 -> data_eis/eis_20110208_153218.head.h5
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# eis_20110208_153218.head.h5.part:   0%|          | 0.00/401k [00:00<?, ?B/s]

# %% [markdown]
# if the code above does not work, you can download the file manually from the following link. Only run this one block below if there is an error in previous block

# %%
# if the code above does not work, you can download the file manually from the following link:
import urllib.request

# Check if EISfile variable is defined
if 'EISfile' not in locals():
    os.makedirs('./data_eis', exist_ok=True)
    url1 = 'https://www.mssl.ucl.ac.uk/~nn2/EIS_Tutorial_data/eis_20110208_153218.data.h5'
    urllib.request.urlretrieve(url1, './data_eis/eis_20110208_153218.data.h5')
    url2 = 'https://www.mssl.ucl.ac.uk/~nn2/EIS_Tutorial_data/eis_20110208_153218.head.h5'
    urllib.request.urlretrieve(url2, './data_eis/eis_20110208_153218.head.h5')

# %% [markdown]
# You can find that the folder 'data_eis' is created and shown on the panel on the left. Inside the folder, you will see two file which ends with .h5. These are the EIS data that we will be using.

# %% [markdown]
# ## Select the dataset and the spectral line we want to fit

# %%
data_filename = './data_eis/eis_20110208_153218.data.h5' # path to the file (don't forget to include folder name)
line = 'fe_12_195_119' # choose the spectral line to look and fit
template = eispac.read_template(eispac.data.get_fit_template_filepath(templates_list[line][0]))

# %% [markdown]
# ## Reading and inspecting the data

# %% [markdown]
# EIS data is stored in a data cube, the axis each hold a different bit of information. Where it says spectral window width this stores the wavelength information of the observations.
# ![level2_datacube.png](data:image/png;base64,...)

# %%
cube = eispac.read_cube(data_filename, window=template.central_wave) # read the data at our desired wavelength
# Out:
# Data file,
#    /content/data_eis/eis_20110208_153218.data.h5
# Header file,
#    /content/data_eis/eis_20110208_153218.head.h5
# Found a wavelength 195.11 [Angstroms] in window 5

# %%
# see the dimensions of the data cube
print(cube.dimensions) # (y-axis, x-axis, wavelength-axis)
# Out:
# [512.  60.  48.] pix
# /usr/local/lib/python3.12/dist-packages/ndcube/ndcube.py:475: NDCubeDeprecationWarning: Replaced by ndcube.NDCube.shape
#   warn_deprecated("Replaced by ndcube.NDCube.shape")

# %%
# see the time of the observations (start,  end)
print(cube.meta['mod_index']['date_beg'], ',' , cube.meta['mod_index']['date_end'])
# Out:
# 2011-02-08T15:32:18.000 , 2011-02-08T16:20:46.000

# %% [markdown]
# Let's look at the spectra profile from one random pixel. This pulls out just the wavelength axis of the data cube for a single pixel.

# %%
ix = 48 # pixel index in the x-axis
iy = 326 # pixel index in the y-axis

spec_inten = cube.data[iy,ix,:] # intensity
spec_wave = cube.wavelength[iy,ix,:] # wavelength
spec_err = cube.uncertainty.array[iy,ix,:] #error


# plot the spectrum
plt.figure()
plt.errorbar(spec_wave, spec_inten, yerr=spec_err, fmt='-')
plt.xlabel('Wavelength [Angstrom]')
plt.ylabel('Intensity')
plt.title(f'Cutout indices: iy = {iy}, ix = {ix}')
plt.ylim(0, 1.1*np.max(spec_inten))
plt.xlim(template.central_wave - 0.5, template.central_wave + 0.5)
plt.axvline(template.central_wave, color='r', linestyle='--', label=f'{template.central_wave:.2f} [$\AA$]')
# Out:
# <>:17: SyntaxWarning: invalid escape sequence '\A'
# <>:17: SyntaxWarning: invalid escape sequence '\A'
# /tmp/ipython-input-65434528.py:17: SyntaxWarning: invalid escape sequence '\A'
#   plt.axvline(template.central_wave, color='r', linestyle='--', label=f'{template.central_wave:.2f} [$\AA$]')

# %% [markdown]
# We can also plot the quicklook of EIS data - to get the idea on what feature Hinode/EIS was looking at when it made observation.
#
# Note that at this stage, we have not done any analysis yet, so this quicklook can't be used for scientific interpretation.

# %%
# sum the data along the wavelength axis to create an image
raster_sum = np.sum(cube.data, axis=2)
# take the log10 of the sum to make the image more visible
scaled_img = np.log10(raster_sum)

plt.figure()
plt.imshow(scaled_img, origin='lower', extent=cube.meta['extent_arcsec'], cmap='plasma')
plt.title(cube.meta['date_obs'][-1])
plt.xlabel('Solar-X [arcsec]')
plt.ylabel('Solar-Y [arcsec]')
plt.colorbar()
plt.show()
# Out:
# /tmp/ipython-input-2973547698.py:4: RuntimeWarning: divide by zero encountered in log10
#   scaled_img = np.log10(raster_sum)
# /tmp/ipython-input-2973547698.py:4: RuntimeWarning: invalid value encountered in log10
#   scaled_img = np.log10(raster_sum)

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## Spectral line fitting
# We now fit the line chosen earlier in each pixel of the EIS dataset.
#
# The line we are fitting is the Fe XII line which has central wavelength 195.11 angstroms

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ### Pop quiz: Which function is suitable for fitting spectral data, and why??
# Try and answer without scrolling down further

# %%
# write your answer here (after the # sign)
#

# %% [markdown]
# ---
#
#
#
# ---

# %%
#check if the fit we want already exists
path = Path(data_filename.replace("data.h5",templates_list[line][0]).replace(".template",f"-{templates_list[line][1]}.fit"))
if path.is_file() == False:
    print('let\'s fit')
    #if the file is not there, fit the line
    cube = eispac.read_cube(data_filename, window=template.central_wave)
    fit_res = eispac.fit_spectra(cube, template, ncpu='max')
    eispac.save_fit(fit_res)
else:
    print('no need to fit')
    #if the file is there already, load it
    cube = eispac.read_cube(data_filename, window=template.central_wave)
    fit_res=eispac.read_fit(path)
# Out:
# let's fit
# Data file,
#    /content/data_eis/eis_20110208_153218.data.h5
# Header file,
#    /content/data_eis/eis_20110208_153218.head.h5
# Found a wavelength 195.11 [Angstroms] in window 5
#  + computing fits for 60 exposures, each with 512 spectra
#  + running mpfit on 2 cores (of 2)
#
#
# Finished computing fits!
#    runtime : 0:03:21.326761
#    24064 spectra fit without issues
#    6656 spectra have < 7 good data points
#    0 spectra have bad or invalid parameters
# Saving EIS fit results...
#    Directory: /content/data_eis
#    Filenames: eis_20110208_153218.fe_12_195_119.2c-0.fit.h5
#               eis_20110208_153218.fe_12_195_179.2c-1.fit.h5
# /usr/local/lib/python3.12/dist-packages/eispac/core/fit_spectra.py:428: RuntimeWarning: invalid value encountered in divide
#   rel_err = obs_errs/obs_cent
# /usr/local/lib/python3.12/dist-packages/eispac/core/fit_spectra.py:428: RuntimeWarning: invalid value encountered in divide
#   rel_err = obs_errs/obs_cent

# %% [markdown]
# ## Some recap while we are waiting for the fitting process.....
#
# We fit spectral lines using a Gaussian function:
#
# $ f(x) = A e^{-\frac{(x-m)^2}{2\sigma^2}}$,
#
# The fitted Gaussian function looks like this:
#
#
# ![Gaussian example.png](data:image/png;base64,...)

# %% [markdown]
# ### Pop Quiz: How can we use the fitted Gaussian to calculate the emission intensity and the doppler velocity of the plasma?

# %%
# write the formula to calculate these values here....... (after the # sign)
#
#

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## Plot the intensity map
# During the fitting process, we calculated the spectral line intensity for each pixel. Remember that the spectral line intensity is the area under the Gaussian curve.

# %% [markdown]
# ---
#
#
#
# ---

# %%
eismap_intensity = fit_res.get_map(component=templates_list[line][1],measurement='intensity')

plt.figure(figsize=(10, 10))
eismap_intensity.plot()
plt.colorbar()
# Out:
# INFO:sunpy:Missing metadata for solar radius: assuming the standard radius of the photosphere.
# INFO:sunpy:Missing metadata for solar radius: assuming the standard radius of the photosphere.
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## Plot the velocity map
#
# During the fitting process, we calculated the spectral line shift for each pixel. Remember that the spectral line shift is the difference between the center of the measured spectral line and the rest wavelength. This gives us information about the plasma velocity.

# %% [markdown]
# ---
#
# ---

# %%
eismap_velocity = fit_res.get_map(component=templates_list[line][1],measurement='velocity')

plt.figure(figsize=(10, 10))
eismap_velocity.plot()
plt.colorbar()
# Out:
# INFO:sunpy:Missing metadata for solar radius: assuming the standard radius of the photosphere.
# INFO:sunpy:Missing metadata for solar radius: assuming the standard radius of the photosphere.
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## Check the line profile from a chosen pixel
#
# You can change the x and y values below to look at the profile of another pixel. Try couple of pixels to see if there are any differences based on the location

# %% [markdown]
# ---
#
#
#
# ---

# %%
y = -520 # solar-y coordinate in arcsec
x = -465 # solar-x coordinate in arcsec

# %%
# Convert the arcsec coordinates to pixel coordinates
arcsec_coordinate = SkyCoord(x*u.arcsec, y*u.arcsec, frame=eismap_intensity.coordinate_frame)
point_coordinates = eismap_intensity.world_to_pixel(arcsec_coordinate)

# Extract raw data (cube)
data_x = cube.wavelength[int(point_coordinates.y.value), int(point_coordinates.x.value), :]
data_y = cube.data[int(point_coordinates.y.value), int(point_coordinates.x.value), :]
data_err = cube.uncertainty.array[int(point_coordinates.y.value), int(point_coordinates.x.value), :]

# Extract fit profile (fit_res) and interpolate fit at higher spectral resolution
fit_x, fit_y = fit_res.get_fit_profile(coords=[int(point_coordinates.y.value),int(point_coordinates.x.value)], num_wavelengths=100)
c0_x, c0_y = fit_res.get_fit_profile(0, coords=[int(point_coordinates.y.value),int(point_coordinates.x.value)], num_wavelengths=100)
c1_x, c1_y = fit_res.get_fit_profile(1, coords=[int(point_coordinates.y.value),int(point_coordinates.x.value)], num_wavelengths=100)
c2_x, c2_y = fit_res.get_fit_profile(2, coords=[int(point_coordinates.y.value),int(point_coordinates.x.value)], num_wavelengths=100)


# Make a multi-panel figure with the cutout and example profile
fig = plt.figure(figsize=[23,8])
plot_grid = fig.add_gridspec(nrows=1, ncols=3, wspace=0.3)

data_subplt1 = fig.add_subplot(plot_grid[0,0], projection=eismap_intensity)
eismap_intensity.plot(axes = data_subplt1)
data_subplt1.scatter(int(point_coordinates.x.value), int(point_coordinates.y.value), color='r', marker='x')

data_subplt2 = fig.add_subplot(plot_grid[0,1], projection=eismap_velocity)
eismap_velocity.plot(axes = data_subplt2)
data_subplt2.scatter(int(point_coordinates.x.value), int(point_coordinates.y.value), color='r', marker='x')


profile_subplt = fig.add_subplot(plot_grid[0,2])
profile_subplt.errorbar(data_x, data_y, yerr=data_err, ls='', marker='o', color='k')
profile_subplt.plot(fit_x, fit_y, color='b', label='Combined profile')
profile_subplt.plot(c0_x, c0_y, color='r', label=fit_res.fit['line_ids'][0])
profile_subplt.plot(c1_x, c1_y, color='r', ls='--', label=fit_res.fit['line_ids'][1])
profile_subplt.plot(c2_x, c2_y, color='g', label='Background')
profile_subplt.set_title(f'Cutout at: x = {x} \'\', y = {y}\'\'')
profile_subplt.set_xlabel('Wavelength [$\AA$]')
profile_subplt.set_ylabel('Intensity ['+cube.unit.to_string()+']')
profile_subplt.legend(loc='upper left', frameon=False)
profile_subplt.set_xlim(template.central_wave - 0.5, template.central_wave + 0.5)
profile_subplt.axvline(template.central_wave, color='r', linestyle='--', label=f'{template.central_wave:.2f} [$\AA$]')

plt.show()
# Out:
# <>:37: SyntaxWarning: invalid escape sequence '\A'
# <>:41: SyntaxWarning: invalid escape sequence '\A'
# <>:37: SyntaxWarning: invalid escape sequence '\A'
# <>:41: SyntaxWarning: invalid escape sequence '\A'
# /tmp/ipython-input-1525900782.py:37: SyntaxWarning: invalid escape sequence '\A'
#   profile_subplt.set_xlabel('Wavelength [$\AA$]')
# /tmp/ipython-input-1525900782.py:41: SyntaxWarning: invalid escape sequence '\A'
#   profile_subplt.axvline(template.central_wave, color='r', linestyle='--', label=f'{template.central_wave:.2f} [$\AA$]')

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## Draw contours on EIS map
# First, define the contour thresholds by intensity.

# %% [markdown]
# ---
#
#
#
# ---

# %%
intensity_level = [200]

# %%
# Make a multi-panel figure with the cutout and example profile
fig = plt.figure(figsize=[15,8])
plot_grid = fig.add_gridspec(nrows=1, ncols=3, wspace=0.3)

data_subplt1 = fig.add_subplot(plot_grid[0,0], projection=eismap_intensity)
eismap_intensity.plot(axes = data_subplt1)
eismap_intensity.draw_contours(intensity_level*eismap_intensity.unit, axes=data_subplt1, cmap='hot', alpha=1.0)

data_subplt2 = fig.add_subplot(plot_grid[0,1], projection=eismap_velocity)
eismap_velocity.plot(axes = data_subplt2)
eismap_intensity.draw_contours(intensity_level*eismap_intensity.unit, axes=data_subplt2, cmap='hot', alpha=1.0)
# Out:
# /usr/local/lib/python3.12/dist-packages/astropy/visualization/wcsaxes/core.py:248: UserWarning: The following kwargs were not used by contour: 'aspect'
#   cset = super().contour(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/astropy/visualization/wcsaxes/core.py:248: UserWarning: The following kwargs were not used by contour: 'aspect'
#   cset = super().contour(*args, **kwargs)

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# #Exercise: find the region with the highest intensity.

# %% [markdown]
# ---
#
#
#
# ---

# %%
# hint: use your observations and try to varies the intensity_level to see the changes in the plot

# %% [markdown]
# Now, define the contour threshold by velocity.

# %%
velocity_level = [-14]

# %%
# Make a multi-panel figure with the cutout and example profile
fig = plt.figure(figsize=[15,8])
plot_grid = fig.add_gridspec(nrows=1, ncols=3, wspace=0.3)

data_subplt1 = fig.add_subplot(plot_grid[0,0], projection=eismap_intensity)
eismap_intensity.plot(axes = data_subplt1)
eismap_velocity.draw_contours(velocity_level*eismap_velocity.unit, axes=data_subplt1, cmap='inferno', alpha=1.0)

data_subplt2 = fig.add_subplot(plot_grid[0,1], projection=eismap_velocity)
eismap_velocity.plot(axes = data_subplt2)
eismap_velocity.draw_contours(velocity_level*eismap_velocity.unit, axes=data_subplt2, cmap='inferno', alpha=1.0)
# Out:
# /usr/local/lib/python3.12/dist-packages/astropy/visualization/wcsaxes/core.py:248: UserWarning: The following kwargs were not used by contour: 'aspect'
#   cset = super().contour(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/astropy/visualization/wcsaxes/core.py:248: UserWarning: The following kwargs were not used by contour: 'aspect'
#   cset = super().contour(*args, **kwargs)

# %% [markdown]
# ### Exercise: find the area with the highest plasma velocity.

# %%
# hint: use your observations and try to varies the velocity_level to see the changes in the plot

# %% [markdown]
# ### Additional Exercise: if you found this easy, then let's try to use the code blocks in previous section and plot the profiles in the regions with high intensity or high velocity.

# %%
# write your code here

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## Bonus: Make a cotemporal AIA map and overplot the field of view of EIS
#
#
# We first download the AIA data from the Virtual Solar Observatory (VSO).
#
# ==**This may not work, depending on how the servers are doing on the day!**==

# %% [markdown]
# ---
#
#
#
# ---

# %%
time_range = a.Time(parse_time(eismap_intensity.meta['date_beg']),parse_time(eismap_intensity.meta['date_beg'])+30*u.minute) # time range for the AIA data, cooresponding to the EIS data

#Download an AIA 193 map
aia_193 = time_range & a.Instrument.aia & a.Wavelength(193*u.angstrom)
aia_193_search = Fido.search(aia_193)
aia_193_result = Fido.fetch(aia_193_search[0][0])
aia_193_map = sunpy.map.Map(aia_193_result[0])
# Out:
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# aia.lev1.193A_2011_02_08T15_32_19.84Z.image_lev1.fits:   0%|          | 0.00/12.1M [00:00<?, ?B/s]

# %% [markdown]
# Then we can plot the image of the Sun, with the field-of-view of EIS overplotted on top in red

# %%
fig = plt.figure(figsize=[10,10])
ax = fig.add_subplot(111, projection=aia_193_map)
aia_193_map.plot(axes=ax)
eismap_intensity.draw_quadrangle(eismap_intensity.bottom_left_coord, top_right = eismap_intensity.top_right_coord, axes=ax, color='r')
# Out:
# /usr/local/lib/python3.12/dist-packages/astropy/visualization/wcsaxes/patches.py:197: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   super().__init__(vertices, **kwargs)

# %% [markdown]
# That's done for today! Hope this module is helpful to you in learning Solar Physics!
